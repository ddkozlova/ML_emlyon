# %%
import pandas as pd
import os
import numpy as np
from datetime import datetime, timedelta, timezone
from time import sleep

# %% [markdown]
# # Data loading

# %%
path = os.getcwd()
path_to_folder = os.path.join(path, "data")

# class 1 represents toxic tweets, class 0 - normal tweets
dataset1 = pd.read_csv(os.path.join(path_to_folder, "toxic-tweets-dataset.csv"), encoding='utf-8')
dataset1.head()
# Out:
#    Unnamed: 0  Toxicity                                              tweet
# 0           0         0   @user when a father is dysfunctional and is s...
# 1           1         0  @user @user thanks for #lyft credit i can't us...
# 2           2         0                                bihday your majesty
# 3           3         0  #model   i love u take with u all the time in ...
# 4           4         0             factsguide: society now    #motivation

# %%
len(dataset1["tweet"].unique())
# Out:
# 54313

# %%
dataset1.shape
# Out:
# (56745, 3)

# %%
dataset1 = dataset1.drop_duplicates(subset = ["tweet"])
dataset1.shape
# Out:
# (54313, 3)

# %%
#class 0 - hate speech, class 1 - offensive language, class 2 - neither
dataset2 = pd.read_csv(os.path.join(path_to_folder, "hate-speech-and-offensive-language-dataset.csv"))
dataset2.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
dataset2.shape
# Out:
# (24783, 7)

# %%
len(dataset2["tweet"].unique())
# Out:
# 24783

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Datasets merging

# %%
dataset1 = dataset1.drop(dataset1.columns[0], axis = 1)

# %%
# tweet is toxic(1) or not(0)
dataset1 = dataset1.rename(columns={"Toxicity": "class"})

# %%
dataset2 = dataset2[["class", "tweet"]]
# 4163 non hate and offensive tweets
dataset2["class"].value_counts()
# Out:
# 1    19190
# 2     4163
# 0     1430
# Name: class, dtype: int64

# %%
dataset2.loc[dataset2["class"] == 0, "class"] = 1
dataset2.loc[dataset2["class"] == 2, "class"] = 0

# %%
dataset2["class"].value_counts()
# Out:
# 1    20620
# 0     4163
# Name: class, dtype: int64

# %% [markdown]
# # Now class 0 is normal tweets and class 1 is toxic/hate/offensive tweets

# %%
df = pd.concat([dataset1, dataset2])
df["class"].value_counts()
# Out:
# 1    44544
# 0    34552
# Name: class, dtype: int64

# %%
df.reset_index(inplace = True, drop=True)

# %%
df.head()
# Out:
#    class                                              tweet
# 0      0   @user when a father is dysfunctional and is s...
# 1      0  @user @user thanks for #lyft credit i can't us...
# 2      0                                bihday your majesty
# 3      0  #model   i love u take with u all the time in ...
# 4      0             factsguide: society now    #motivation

# %% [markdown]
# Slightly imbalanced (55% normal tweets vs 45% toxic tweets)

# %% [markdown]
# ## Data cleaning and transformation

# %% [markdown]
# ### Punctuation, URLs and tags removal

# %%
# deleted @users, #hashtags and non-supported (non-alphanumeric) characters
# PROBLEM: (word) is also deteled
def clean_text(X):
    X = X.lower().split()
    X_clean = filter(str.isalnum, X)
    return ' '.join(X_clean)

result = []
for row in df.loc[:,"tweet"]:
    result.append(clean_text(row))

# %%
df["clean_tweet"] = result

# %%
df.head()
# Out:
#    class                                              tweet  \
# 0      0   @user when a father is dysfunctional and is s...
# 1      0  @user @user thanks for #lyft credit i can't us...
# 2      0                                bihday your majesty
# 3      0  #model   i love u take with u all the time in ...
# 4      0             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0  when a father is dysfunctional and is so selfi...
# 1  thanks for credit i use cause they offer wheel...
# 2                                bihday your majesty
# 3               i love u take with u all the time in
# 4                                        society now

# %% [markdown]
# ### Stop words removal

# %%
from nltk.corpus import stopwords
stopwords_list = stopwords.words('english')
newStopWords = ["rt"]
stopwords_list.extend(newStopWords)

def remove_stop_words(X):
    X = X.split()
    X_new = [x for x in X if x not in stopwords_list]
    return ' '.join(X_new)

result = []
for row in df.loc[:,"clean_tweet"]:
    result.append(remove_stop_words(row))
    
df["final_tweet"] = result

# %%
df.drop(columns = ["tweet", "clean_tweet"], inplace = True)
df.head()
# Out:
#    class                                    final_tweet
# 0      0        father dysfunctional selfish drags kids
# 1      0  thanks credit use cause offer wheelchair vans
# 2      0                                 bihday majesty
# 3      0                             love u take u time
# 4      0                                        society

# %% [markdown]
# Some values are non NA but empty strings (as the result of data preprocessing, so they should be deleted):

# %%
nan_value = float("NaN")
df.replace("", nan_value, inplace=True)
df.dropna(subset = ["final_tweet"], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df["class"].value_counts()
# Out:
# 1    44171
# 0    33054
# Name: class, dtype: int64

# %%
df.to_csv(os.path.join(path_to_folder, "final_dataset.csv"), encoding='utf-8', index = False)

# %% [markdown]
# # Feature extraction and training of ML models

# %% [markdown]
# ## Simple count method

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
cv = CountVectorizer()

# %%
X_cv = cv.fit_transform(df["final_tweet"])

# %%
X_cv.shape
# Out:
# (77225, 26894)

# %%
from sklearn import model_selection, naive_bayes, svm
train_x, test_x, train_y, test_y = model_selection.train_test_split(X_cv, df["class"], test_size = 0.25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

LG = LogisticRegression(max_iter = 500)
param_grid_lg = {"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}
grid_lg = GridSearchCV(LG, param_grid_lg, cv = 10)

# fitting the model for grid search 
grid_lg.fit(train_x, train_y) 
 
# print best parameter after tuning 
print(grid_lg.best_params_) 
grid_predictions = grid_lg.predict(test_x) 
   
# print classification report 
print(classification_report(test_y, grid_predictions))
# Out:
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 70 fits failed out of a total of 140.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 70 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Daria\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Daria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Daria\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.83885824        nan 0.86054412        nan 0.88462996
#         nan 0.89894338        nan 0.90182678        nan 0.89291761
#         nan 0.88599402]
#   warnings.warn(
# {'C': 10.0, 'penalty': 'l2'}
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      8213
#            1       0.93      0.90      0.91     11094
#
#     accuracy                           0.90     19307
#    macro avg       0.90      0.90      0.90     19307
# weighted avg       0.90      0.90      0.90     19307

# %%
NB = naive_bayes.MultinomialNB()
NB.fit(train_x, train_y)
predictions = NB.predict(test_x)

# %%
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85      8213
#            1       0.88      0.91      0.89     11094
#
#     accuracy                           0.88     19307
#    macro avg       0.88      0.87      0.87     19307
# weighted avg       0.88      0.88      0.88     19307

# %%
SVM = svm.SVC(kernel='linear')
SVM.fit(train_x, train_y)
predictions = SVM.predict(test_x)

# %%
from sklearn.metrics import classification_report
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      8213
#            1       0.93      0.89      0.91     11094
#
#     accuracy                           0.90     19307
#    macro avg       0.90      0.90      0.90     19307
# weighted avg       0.90      0.90      0.90     19307

# %% [markdown]
# ## TF-IDF method

# %%
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(df["final_tweet"])

# %%
train_x, test_x, train_y, test_y = model_selection.train_test_split(X_tfidf, df["class"], test_size = 0.25)

# %%
LG.fit(train_x, train_y)
predictions = LG.predict(test_x)

# %%
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88      8274
#            1       0.95      0.86      0.90     11033
#
#     accuracy                           0.89     19307
#    macro avg       0.89      0.90      0.89     19307
# weighted avg       0.90      0.89      0.90     19307

# %%
NB.fit(train_x, train_y)
predictions = NB.predict(test_x)

# %%
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80      8274
#            1       0.82      0.94      0.88     11033
#
#     accuracy                           0.85     19307
#    macro avg       0.86      0.83      0.84     19307
# weighted avg       0.85      0.85      0.84     19307

# %%
SVM.fit(train_x, train_y)
predictions = SVM.predict(test_x)

# %%
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      8717
#            1       0.95      0.87      0.91     11057
#
#     accuracy                           0.90     19774
#    macro avg       0.90      0.90      0.90     19774
# weighted avg       0.90      0.90      0.90     19774

# %% [markdown]
# # Saving the best model

# %%
import pickle
Pkl_Filename = "svm_model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(SVM, file)

# %% [markdown]
# # Example of applying the model to unseen tweets

# %% [markdown]
# ## Setting up Twitter connection

# %% [markdown]
# https://developer.twitter.com/en/docs/tutorials/step-by-step-guide-to-making-your-first-request-to-the-twitter-api-v2

# %%
search_term = input("Type the topic: ")
# Out:
# Type the topic: cat

# %%
#start_time = (datetime.now(timezone.utc).astimezone() - timedelta(seconds=50)).isoformat()
end_time = (datetime.now(timezone.utc).astimezone() - timedelta(seconds=10)).isoformat()

# %%
end_time
# Out:
# '2022-04-21T11:15:37.303057+02:00'

# %%
import requests
import os
import json

bearer_token = "AAAAAAAAAAAAAAAAAAAAAKovZQEAAAAAWKm9VUw8iFuu27OQ1m34HwIR5VY%3DbPl1vQZq69vtsvc5JPq5HD9AiatIKCw58RBeXOugqsl5Holcog"

search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

#change params based on the endpoint you are using
query_params = {'query': search_term,
                #'start_time': start_time,
                'end_time': end_time,
                'max_results': '100',
                'tweet.fields': 'text,geo,created_at,lang,public_metrics,source',
                'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                'next_token': {}}


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params, next_token = None):
    response = requests.get(url, auth=bearer_oauth, params=params)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


json_response = connect_to_endpoint(search_url, query_params)

# %%
json_response
# Out:
# {'data': [{'source': 'Twitter for iPhone',
#    'text': '.@sea_cat_boo https://t.co/wBg9SGDZHZ',
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069532451545088',
#    'lang': 'und'},
#   {'source': 'Twitter Web App',
#    'text': 'RT @NewVoiceUkraine: Do you remember the charred cat from Kyiv region, the photo of which flew around the world? He has a new life now 🐈❤…',
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 54,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069531562319872',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @Lemon0517ch: リモート会議してるとこうなるので困ってます...\n\n#猫\u3000#cat https://t.co/96kbi7zuM7',
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 5687,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069531289878528',
#    'lang': 'ja'},
#   {'source': 'Twitter for Android',
#    'text': "RT @iSabadellcat: [Els finalistes del Premi Sabadellenc de l'Any] @Maica_GG, waterpolista del @CN_Sabadell: història viva de l'esport femen…",
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069530605961218',
#    'lang': 'ca'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @villannefer: school of the cat https://t.co/7gP0HYaYur',
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 20,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069530341773313',
#    'lang': 'en'},
#   {'source': 'Twitter Web App',
#    'text': 'RT @Lemon0517ch: リモート会議してるとこうなるので困ってます...\n\n#猫\u3000#cat https://t.co/96kbi7zuM7',
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 5687,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069529779691520',
#    'lang': 'ja'},
#   {'source': 'Twitter for iPhone',
#    'text': "RT @agustranda: namjoon posted a cat tagging yoongi. yoongi said he'd probably name his cat sugar. namjoon calls yoongi sugar. both namgi p…",
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 121,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069529205338115',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @aretteepls: The Ishgardian Orthodox HOA when they see a pastel pink giga-mansion with a naked cat girl in a hot tub on the front lawn g…',
#    'created_at': '2022-04-21T09:15:36.000Z',
#    'public_metrics': {'retweet_count': 909,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069528697614336',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @Lemon0517ch: リモート会議してるとこうなるので困ってます...\n\n#猫\u3000#cat https://t.co/96kbi7zuM7',
#    'created_at': '2022-04-21T09:15:35.000Z',
#    'public_metrics': {'retweet_count': 5687,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069526533554176',
#    'lang': 'ja'},
#   {'source': 'Twitter for iPhone',
#    'text': "RT @TheFigen: The other cat's face like WTF!   ❤️🤣🤣https://t.co/qSp1pTbOLc",
#    'created_at': '2022-04-21T09:15:35.000Z',
#    'public_metrics': {'retweet_count': 1593,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069526268977152',
#    'lang': 'en'},
#   {'source': 'Microsoft Power Platform',
#    'text': '子猫に悪戯を注意したら逆ギレされたので喧嘩になりました。笑\nhttps://t.co/wlcUZsTqfc\n投稿主：みるきーちゃんねる【Minuetミヌエット】\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:35.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069525744640000',
#    'lang': 'ja'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @ECOAlphaTango: CCP CHINA 🇨🇳👹🇨🇳| ANIMAL ABUSE 🩸\n\nThat is Vile, Barbaric, Sadistic, Evil and Pure Insanity. \n\nYou eat dog/cat meat? so yo…',
#    'created_at': '2022-04-21T09:15:35.000Z',
#    'public_metrics': {'retweet_count': 22,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069525266612224',
#    'lang': 'en'},
#   {'source': 'Twitter Web App',
#    'text': 'missing my cat please nak balik penang https://t.co/vyQnxvHr9X',
#    'created_at': '2022-04-21T09:15:35.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069524989726720',
#    'lang': 'en'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'Cat 🐱- 怠けものなシャミ^ ^😅샤미가 놀이 방법을 바꿨대요 😜\nhttps://t.co/74ByLKRqIG\n投稿主：[ほしhouse]\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:35.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069524276719616',
#    'lang': 'ja'},
#   {'source': 'Twitter Web App',
#    'text': 'RT @mlem_____: Squish that cat meme but dragonli\n#zhongli #Morax #Childe #GenshinImpact #原神 https://t.co/T1pRxP01DP',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 944,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069523886776320',
#    'lang': 'en'},
#   {'source': 'Twitter Web App',
#    'text': 'RT @fbrunes: De tu a tu  és més fàcil https://t.co/mBAzTA9IwV via @elpuntavui',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069523828056064',
#    'lang': 'ca'},
#   {'source': 'Microsoft Power Platform',
#    'text': '春キャベツの美味しい食べ方😋😂 そのままでも甘くてシャキシャキで最高ですよね〜😁🐕 ある意味贅沢な食べ方✨ #柴犬 #春 #キャベツ #レシピ #簡単 #グルメ 最高\nhttps://t.co/ddSiFaSnj2\n投稿主：柴犬コロと猫のあんこ\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069523362279424',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '狩猟本能剥き出しで獲物を仕留める猫。猫キック(ケリケリ)『エアはるHOUSE』保護猫×チワワ×子どもの日常\nhttps://t.co/JwuvB2Ej5Y\n投稿主：エアはるHOUSE～猫とチワワの日常〜\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069523244834816',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'セルフカット終わりに爪切りもしたら...#shorts #cat\nhttps://t.co/rSF6jlpdV1\n投稿主：犬派妻を虜にした猫【ぽんすけ】\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522963886080',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'カメラが気になる猫🐈️#shorts登録希望\nhttps://t.co/67XODPRtRT\n投稿主：Maron-Channel\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522842226689',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'じっと出来ない猫ちゃん！\nhttps://t.co/nureQCnxnm\n投稿主：RX-8ドライブチャンネル\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522804436992',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'ギャン泣きする子猫に心打たれて出発遅れました\nhttps://t.co/eT9KFWl5Jv\n投稿主：とらねこものがたり\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522779340800',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'お姉ちゃんの足が大好きみたいですw\nhttps://t.co/0QLj6HPfnL\n投稿主：にゃるがくるが・ちゃんねる\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522758373376',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '生後１ヶ月と3ヶ月の子猫のじゃれ合いが全然違った。\u3000The play of 1-month-old and 3-month-old kittens was completely different.\nhttps://t.co/DRnxQCUnCn\n投稿主：3匹の猫と黒いオジサン\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522733191168',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'ヘソ天の儀でひっくり返ってる猫たち\nhttps://t.co/3lUZD5jvuc\n投稿主：テテさんとくぅちゃん\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522724810754',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'カメラが気になる猫🐈️#shorts登録希望\nhttps://t.co/JysRUUKuQp\n投稿主：Maron-Channel\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522573815808',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '私たちペロペロが止まらないニャー😸 We licking do not stop 😸 #shorts\nhttps://t.co/z1dBzPCJYj\n投稿主：AKI46POV\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522569555968',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'ついに鳴らすベルを選び始めた天才猫の黒猫モカ\u3000505話\nhttps://t.co/7w5vZGRUrc\n投稿主：はぴ猫日記\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522561241088',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'にゃんこがソファーカバーの下に潜りたいとお願いしてきました\nhttps://t.co/zfDhZgDeik\n投稿主：とらまるらんまる\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522535997440',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': "vol.3第1回 最強の猫じゃらし決定戦(パフォーマンス編) 2022春光戦/準々決勝〜準決勝【ラグドール】Ragdoll cats' favorite toy catnip tournament！\nhttps://t.co/3qMv64Drkk\n投稿主：ましゅまろの家【Marshmallow Ragdoll Cat】\n#猫 #cat",
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522473132032',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '猫かわいい\u3000ひたすらじっと待つ\nhttps://t.co/KE8t284Vsa\n投稿主：がんばれジミー\u3000癌と告知された老猫とアラ還猫のvlog日記\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522431143936',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '猫がふみふみする理由\nhttps://t.co/LeF4qwiuwt\n投稿主：かっぱちゃんねる\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522426990592',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '野良猫動画 白キジ達がぞくぞくとやってきて順番に餌を食べる  White and brown tabby cat come one after another and eat cat food\nhttps://t.co/grMMteKIPZ\n投稿主：野良猫とおっさん\u3000Stray cat with middle-aged man\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522372493313',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'カメラが気になる猫🐈️#shorts登録希望\nhttps://t.co/6wlU5vbq0j\n投稿主：Maron-Channel\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522309578753',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '[子猫] 緊急でお預かりしたキジトラ乳飲み子2匹の授乳！ [保護猫]\nhttps://t.co/7e5g3rBs6F\n投稿主：ねころび荘放送室\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522284343296',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '対決！子猫ｖｓ旦那の足！！【保護猫】\nhttps://t.co/llucJF2ue5\n投稿主：こはくびより\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522183737345',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '朝から元気な子猫に癒されます\nhttps://t.co/CyRApc3hFN\n投稿主：ももんの時間\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069522116636673',
#    'lang': 'ja'},
#   {'source': 'Twitter for Android',
#    'text': "RT @agustranda: namjoon posted a cat tagging yoongi. yoongi said he'd probably name his cat sugar. namjoon calls yoongi sugar. both namgi p…",
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 121,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521949184000',
#    'lang': 'en'},
#   {'source': 'Microsoft Power Platform',
#    'text': '子猫がおもちゃに本気で挑む「秘技 ねこ拳法」（Cat kung fu）\nhttps://t.co/Co2ggkHCyi\n投稿主：ろとの冒険（The Adventures of Loto）\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521474834432',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '猫が出産する, 猫の出産, short51\nhttps://t.co/pBjmqnPoeQ\n投稿主：猫の出産\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521403609088',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '腎臓病の保護猫に○○をしたら劇的な変化が起こりました【朗報】\nhttps://t.co/JS5qi6d2V5\n投稿主：Lumi Towncat\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521365856256',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '【猫のための音楽】落ち着かない猫ちゃんや眠れない子猫ちゃんをリラックスさせる音楽[528Hz]\nhttps://t.co/n2weXlsVIt\n投稿主：ねこちゃんねる＊猫のための癒しの音楽\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521328087040',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '【3兄弟】動くおもちゃを本物の動物だと勘違いした猫と子猫と犬の反応\nhttps://t.co/eDrDWPtqLu\n投稿主：セナ猫channel\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521311322114',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '先住猫と新入り猫を会わせてみた！\nhttps://t.co/zrqAjMwTL3\n投稿主：シンバとフィガロのドタバタ劇場\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521286098944',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'お薬でへんな顔になる猫（サイベリアンのイギー）\nhttps://t.co/plzVVJkk9d\n投稿主：かわイギーの時止めちゃんねる\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521286094848',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '《第898回》相性激悪の猫2匹をちょっと黙って見てみたら・・・。\nhttps://t.co/hqMIBKxEc5\n投稿主：【ニャンズNo.6】ニャンズpapa\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521269403648',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '【猫の病気\u3000最新版】知らないとマズい?!猫の一生を通して気を付けたい病気\nhttps://t.co/NsSGKC8Gtx\n投稿主：黒猫ココ&amp;ルル\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521260978177',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '幸せな時間を満喫し過ごすとこうなりました\nhttps://t.co/LrYBQhvD6N\n投稿主：うみちゃんねる\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521252610049',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '福岡が一望できる素敵な場所で家族との最期のお別れに...ペット葬祭場にじの花さんにお邪魔しました\nhttps://t.co/Xt8Q0Q6kFb\n投稿主：人生はねこだらけ【動物愛護団体キーテイル】\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521185505281',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': '子猫が肉球みせつけてくる😍 the kitten paw pad #shorts\nhttps://t.co/glY5wvbtVw\n投稿主：毛玉あんこ\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521160327169',
#    'lang': 'ja'},
#   {'source': 'Microsoft Power Platform',
#    'text': 'ケンカを仕掛けても反撃される子猫様がこちらですw\nhttps://t.co/qIT5eMsJhM\n投稿主：ノンとチャチャの日常\n#猫 #cat',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069521147744256',
#    'lang': 'ja'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @yjwprnts: jungwon cat bed selcas 💤 https://t.co/uBKLxZzg4j',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 1548,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069520594436101',
#    'lang': 'en'},
#   {'source': 'Twitter Web App',
#    'text': "#MePoo in my litter tray as I'm a good cat. https://t.co/2fOK7nDAhy",
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069520522911745',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @VilaWeb: ▶️VÍDEO I Borràs reclama de trencar el pacte de Junts amb el PSC a la Diputació de Barcelona https://t.co/ZWGNEMGLdG',
#    'created_at': '2022-04-21T09:15:34.000Z',
#    'public_metrics': {'retweet_count': 32,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069520237649921',
#    'lang': 'ca'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @James800707: 第三世多杰羌佛文化藝術館\n佛教正法中心 第三世多杰羌佛文化藝術館\n\n#第三世多杰羌佛 #第三世多杰羌佛文化藝術館 #義雲高 #義雲高大師正法中心 第三世多杰羌佛文化藝術館 https://t.co/H5qQOxeB3n',
#    'created_at': '2022-04-21T09:15:33.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069518832476164',
#    'lang': 'zh'},
#   {'source': 'TweetDeck',
#    'text': 'RT @Eurecat_news: El projecte europeu @ClimateImpetus desenvolupa activitats d’adaptació i mitigació per ajudar a la costa catalana a adapt…',
#    'created_at': '2022-04-21T09:15:33.000Z',
#    'public_metrics': {'retweet_count': 3,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069518010523649',
#    'lang': 'ca'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @agu_agu0718: 目がクリクリ🐈️\n#猫 #保護猫 #ねこ #cat #猫のいる暮らし #猫好きさんと繋がりたい https://t.co/ZxQ4b1KAW5',
#    'created_at': '2022-04-21T09:15:33.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069516936970242',
#    'lang': 'ja'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @futaba_comiket: 🎁レトルトとしんちゃんのコラボ記念‼️缶バッジセットを３名様に🎁\n\n応募方法\n@futaba_comiket\nをフォロー＆このツイートをＲＴ\n\n〆切\n５月５日\n\n絶賛販売中👇\n\nレトルトストア\nhttps://t.co/tfXA52Rx0…',
#    'created_at': '2022-04-21T09:15:33.000Z',
#    'public_metrics': {'retweet_count': 104,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069516672757760',
#    'lang': 'ja'},
#   {'source': 'Twitter for Android',
#    'text': '@juantrompe_juan @Pacopeko55 @Ttrifasika @Veromaggi @PilarPalomoMuo1 @PepaGM46 @ISABELBM10 @JorgeConstanza4 @Witowito71 @bustingorri721 @Libroabierto12 @cat_kart Será el tiempo. Pobre  si es mas bueno, también. Ves con cuidado hoy con el camión.🤝🤗😘😘😘',
#    'created_at': '2022-04-21T09:15:32.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069511782023169',
#    'lang': 'es'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @meowniments: human playing with cat that has saggy fat pouch tummy stomach belly alien noises sim language simlish audio yama nama doo…',
#    'created_at': '2022-04-21T09:15:31.000Z',
#    'public_metrics': {'retweet_count': 16160,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069511295664128',
#    'lang': 'en'},
#   {'source': 'Twitter Web App',
#    'text': "Gall of the week is caused by the cynipid Phanacis hypochoeridis on common cat's-ear Hypochaeris radicata. \nPhoto by Mike Poulton. https://t.co/oQgFE6KaTo",
#    'created_at': '2022-04-21T09:15:31.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069511169609728',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @MsPeachyDBN: Going LIVE TONIGHT @ 10pm (CAT)\n\n   50% OFF SALE ON RIGHT NOW \n       ➡️https://t.co/j7FCXyIFsh ⬅️\n\n https://t.co/oa2X2Yrn…',
#    'created_at': '2022-04-21T09:15:31.000Z',
#    'public_metrics': {'retweet_count': 8,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069510704078848',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @meowniments: hehe not hehe cat kitten video kitten staring looking at camera thoughtlessly no thoughts blankly https://t.co/IHZY22hCGX',
#    'created_at': '2022-04-21T09:15:31.000Z',
#    'public_metrics': {'retweet_count': 26649,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069507667369984',
#    'lang': 'en'},
#   {'source': 'SocialRabbit Plugin',
#    'text': '#inspiration #interiordecor #designdeinteriores Cat Scratcher Refill Pad - 2 Pack https://t.co/dMjJKIiKEH https://t.co/KdYTy9mZmX',
#    'created_at': '2022-04-21T09:15:31.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069507499638785',
#    'lang': 'en'},
#   {'source': 'Twitter Web App',
#    'text': 'RT @meowniments: cat floating swimming in swimming pool water wearing shark suit life jacket with shark fin italian music dolce nonna https…',
#    'created_at': '2022-04-21T09:15:31.000Z',
#    'public_metrics': {'retweet_count': 5716,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069507390750720',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': '@scvenwithyou intro: do you want to see my cat ?',
#    'created_at': '2022-04-21T09:15:30.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069506576887808',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @yjwprnts: jungwon cat bed selcas 💤 https://t.co/uBKLxZzg4j',
#    'created_at': '2022-04-21T09:15:30.000Z',
#    'public_metrics': {'retweet_count': 1548,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069505335234560',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @maigo_pet_dog: 【迷子猫の掲示板】茨城県ひたちなか市でキジトラが迷子です。情報提供と拡散お願いします！ #迷子猫 #迷い猫 #茨城県 https://t.co/GXsGLqqUsc',
#    'created_at': '2022-04-21T09:15:29.000Z',
#    'public_metrics': {'retweet_count': 268,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069502273388544',
#    'lang': 'ja'},
#   {'source': 'Twitter Web App',
#    'text': 'RT @VilaWeb: 🗣 "El PP té un problema, i és que no sap què fer amb Vox. I això ho ha escenificat Núñez Feijóo mateix"\n\nEntrevista a Xavier C…',
#    'created_at': '2022-04-21T09:15:29.000Z',
#    'public_metrics': {'retweet_count': 3,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069501770211328',
#    'lang': 'ca'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @gentleeeeeeecat: protractor cat 📐 https://t.co/gJDXLjE76S',
#    'created_at': '2022-04-21T09:15:29.000Z',
#    'public_metrics': {'retweet_count': 4832,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069501208367104',
#    'lang': 'es'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @meowniments: cat floating swimming in swimming pool water wearing shark suit life jacket with shark fin italian music dolce nonna https…',
#    'created_at': '2022-04-21T09:15:28.000Z',
#    'public_metrics': {'retweet_count': 5716,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069498372825090',
#    'lang': 'en'},
#   {'source': 'TweetDeck',
#    'text': '📌 @joanignasielena: “S’ha detingut l’agressor sexual d’Igualada perquè no hi ha hagut cap filtració”\n\n➡️ L’alcalde, @marccastells, diu que farà tot el que pugui per castigar el crim i que li caigui tot el pes de la llei\n\nhttps://t.co/FgPrZYqueL',
#    'created_at': '2022-04-21T09:15:28.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069498079133696',
#    'lang': 'ca'},
#   {'source': 'PetsReunited',
#    'text': '£50 REWARD! Lost Grey cat called Billie - Hammersmith area, Hammersmith &amp; Fulham https://t.co/1poNOFF2h9. Please RT! #lostcats #lostpets #lostandfoundpets #catsmatter #Hammersmith',
#    'created_at': '2022-04-21T09:15:28.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069496552460289',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @MelenaMariaRya_: Do you like my pussy cat ? 🐈\u200d⬛ https://t.co/o3IbNvW2L5',
#    'created_at': '2022-04-21T09:15:28.000Z',
#    'public_metrics': {'retweet_count': 162,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069496434970624',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @yamadataro43: 【第492回】緊急特集！月曜日のたわわ国連女性機関、抗議問題（2022/04/20）\nhttps://t.co/eD7G6FVcvL\n\n資料はこちら📁\nhttps://t.co/PO4nkqA9xV\n\n#山田太郎のさんちゃんねる \n#赤松健…',
#    'created_at': '2022-04-21T09:15:28.000Z',
#    'public_metrics': {'retweet_count': 271,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069496087097344',
#    'lang': 'ja'},
#   {'source': 'Twitter for iPad',
#    'text': '@H_the_Cat https://t.co/MI3N1i6zYh',
#    'created_at': '2022-04-21T09:15:28.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069495374073856',
#    'lang': 'und'},
#   {'source': 'Twitter for Android',
#    'text': "@acorey_cat Veient la resposta dels partits del procés el primer pas l'hem de fer els catalans, fer perdre el control de les institucions al processisme i donar pas a una nova generació d'homes i dones disposats a tot per Catalunya. Propera cita eleccions municipals 2023. Si puc @CatalunyaAC",
#    'created_at': '2022-04-21T09:15:27.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069494497259520',
#    'lang': 'ca'},
#   {'source': 'Twitter for Android',
#    'text': 'Apparently going blehpblehblehblebblehp summons my cat',
#    'created_at': '2022-04-21T09:15:27.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069494262267904',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': '@cat_mirage 猫の蜃気楼さんおはありでした〜✨☺️',
#    'created_at': '2022-04-21T09:15:27.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069492748447744',
#    'lang': 'ja'},
#   {'source': 'Twitter for Android',
#    'text': '@jkbun_ bts cypher pt 5 : cats, or ft doja cat?!',
#    'created_at': '2022-04-21T09:15:27.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069491662123008',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @josepmas8: el Col·lectiu Maspons i Anglasell @Col_Maspons, ha redactat el  manifest - “Pel català a l’escola, rebutgem la proposició de…',
#    'created_at': '2022-04-21T09:15:27.000Z',
#    'public_metrics': {'retweet_count': 11,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069491372445696',
#    'lang': 'ca'},
#   {'source': 'Twitter Web App',
#    'text': "@havinfunontwitr @BurgonCatherine @hannahsimpsloki @darkmoonloki @black_cat_jo @Divine_965 We need more wardrobe changes in general, he looks so good in most things! I hope he'll come back into the movies as Sacred Timeline Loki so we can get some Asgardian leather and some designer suits again.",
#    'created_at': '2022-04-21T09:15:27.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069490680475649',
#    'lang': 'en'},
#   {'source': 'TweetDeck',
#    'text': 'RT @elMonEsport: 🔵🔴 Quan i on veure el Reial Societat-Barça\n\nhttps://t.co/6xpmtgXowH',
#    'created_at': '2022-04-21T09:15:26.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069489929605121',
#    'lang': 'ca'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @Alabiistired: The cat ownership in Lagos is screaming peer pressure.',
#    'created_at': '2022-04-21T09:15:26.000Z',
#    'public_metrics': {'retweet_count': 78,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069488453296129',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': 'Opacidad total en el BCN Market: la web ni siquiera funciona https://t.co/7MiYPrp7K5 otro “marketplace para competir con Amazon” para la lista de @JaimeObregon',
#    'created_at': '2022-04-21T09:15:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069488440623110',
#    'lang': 'es'},
#   {'source': 'Holamon.cat CA',
#    'text': "S'entén per dissolució de Txecoslovàquia la dissolució de l'antic estat de Txecoslovàquia, esci...\nhttps://t.co/26n4G434XH\n\n #viatjar #Dissolució #de #Txecoslovàquia https://t.co/M63yYmXaA2",
#    'created_at': '2022-04-21T09:15:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069488159698944',
#    'lang': 'ca'},
#   {'source': 'Twitter',
#    'text': 'Let it #beYourSoulCat #adoptdontshop  RT @timhlan: I suggest that people adopt a cat from the animal shelter if lonely.  You’ll never be lonely if you have a cat at h… https://t.co/00KXXU8nKU',
#    'created_at': '2022-04-21T09:15:25.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069485416587265',
#    'lang': 'en'},
#   {'source': 'TweetDeck',
#    'text': 'RT @mon_gent: Denúncia desesperada de María Patiño: "M\'estan vexant, humiliant i assetjant" https://t.co/I2851RGgFt',
#    'created_at': '2022-04-21T09:15:25.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069485030707201',
#    'lang': 'ca'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @vkoobuns: never ending saga of yoongi cat agenda 😿💔 https://t.co/EiCSqhZrkV',
#    'created_at': '2022-04-21T09:15:25.000Z',
#    'public_metrics': {'retweet_count': 5297,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069484561149953',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @princess48thfc: {👑🐱} https://t.co/yzDusaCerQ\nプリンセス\n\nไม่ใช่ของหญิง 😗\nig story : #FortuneCGM48\nw/ #HomnuanCGM48 #BlueciferCGM48 \n\n#TeamPr…',
#    'created_at': '2022-04-21T09:15:25.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069484481454080',
#    'lang': 'ja'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @CatalunyaPlural: 📚🌹Per #SantJordi inspirem la curiositat lectora\n\n👉 Recuperem la conversa amb @CarolinaMeloni1, autora de “Feminismos F…',
#    'created_at': '2022-04-21T09:15:25.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069483982176258',
#    'lang': 'ca'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @beverlylove: doja cat https://t.co/EnyBN8sAUu',
#    'created_at': '2022-04-21T09:15:25.000Z',
#    'public_metrics': {'retweet_count': 8927,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069482887364608',
#    'lang': 'ca'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @meowniments: cat floating swimming in swimming pool water wearing shark suit life jacket with shark fin italian music dolce nonna https…',
#    'created_at': '2022-04-21T09:15:24.000Z',
#    'public_metrics': {'retweet_count': 5716,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069481595572224',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': "RT @NYCDEATHROWCATS: *SHELTER PLEA* Don't let Brady feel forgotten! Sweet boy afraid and in need of some one-on-one care. Mr. Brady was lef…",
#    'created_at': '2022-04-21T09:15:24.000Z',
#    'public_metrics': {'retweet_count': 33,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069479120977920',
#    'lang': 'en'},
#   {'source': 'holamon.cat',
#    'text': 'The Dissolution of Czechoslovakia (Czech: Rozdělení Československa, Slovak: Rozdelenie Česko-Slo...\nhttps://t.co/b4CmNXtMUp\n\n #travel #Dissolution #of #Czechoslovakia https://t.co/6JptXMCXGi',
#    'created_at': '2022-04-21T09:15:24.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069478240165888',
#    'lang': 'cs'},
#   {'source': 'Twitter for iPhone',
#    'text': 'RT @Alabiistired: The cat ownership in Lagos is screaming peer pressure.',
#    'created_at': '2022-04-21T09:15:23.000Z',
#    'public_metrics': {'retweet_count': 78,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069477925376000',
#    'lang': 'en'},
#   {'source': 'Twitter for iPhone',
#    'text': 'bts also supports the cat agenda and we are thriving 🤘🏻✨',
#    'created_at': '2022-04-21T09:15:23.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069477346643969',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @vkoobuns: never ending saga of yoongi cat agenda 😿💔 https://t.co/EiCSqhZrkV',
#    'created_at': '2022-04-21T09:15:23.000Z',
#    'public_metrics': {'retweet_count': 5297,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069477158223872',
#    'lang': 'en'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @SBolsri: เป็นคลิปแรกของช่อง STUDIO CHOOM\nเลื่อนสุดกว่านี้ไม่ได้แล้วจ้า เป็นช่องที่ไอดอลมาเต้นกันทุกคัมแบ็ค และมี Artist of the month…',
#    'created_at': '2022-04-21T09:15:23.000Z',
#    'public_metrics': {'retweet_count': 207,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069476432596992',
#    'lang': 'th'},
#   {'source': 'Twitter for Android',
#    'text': 'RT @buitengebieden_: Every single cat ever.. 😅 https://t.co/zQjv2tlLvb',
#    'created_at': '2022-04-21T09:15:23.000Z',
#    'public_metrics': {'retweet_count': 7050,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1517069475052494848',
#    'lang': 'en'}],
#  'meta': {'newest_id': '1517069532451545088',
#   'oldest_id': '1517069475052494848',
#   'result_count': 100,
#   'next_token': 'b26v89c19zqg8o3fpytnyll6oqrp8df1nvb31vs0wriwt'}}

# %% [markdown]
# ## Loading and cleaning the data

# %%
tweets = pd.DataFrame.from_dict(json_response["data"])

# %%
tweets
# Out:
#                  source                                               text  \
# 0    Twitter for iPhone              .@sea_cat_boo https://t.co/wBg9SGDZHZ
# 1       Twitter Web App  RT @NewVoiceUkraine: Do you remember the charr...
# 2    Twitter for iPhone  RT @Lemon0517ch: リモート会議してるとこうなるので困ってます...\n\n#...
# 3   Twitter for Android  RT @iSabadellcat: [Els finalistes del Premi Sa...
# 4   Twitter for Android  RT @villannefer: school of the cat https://t.c...
# ..                  ...                                                ...
# 95   Twitter for iPhone  RT @Alabiistired: The cat ownership in Lagos i...
# 96   Twitter for iPhone  bts also supports the cat agenda and we are th...
# 97  Twitter for Android  RT @vkoobuns: never ending saga of yoongi cat ...
# 98  Twitter for Android  RT @SBolsri: เป็นคลิปแรกของช่อง STUDIO CHOOM\n...
# 99  Twitter for Android  RT @buitengebieden_: Every single cat ever.. 😅...
#
#                   created_at  \
# 0   2022-04-21T09:15:36.000Z
# 1   2022-04-21T09:15:36.000Z
# 2   2022-04-21T09:15:36.000Z
# 3   2022-04-21T09:15:36.000Z
# 4   2022-04-21T09:15:36.000Z
# ..                       ...
# 95  2022-04-21T09:15:23.000Z
# 96  2022-04-21T09:15:23.000Z
# 97  2022-04-21T09:15:23.000Z
# 98  2022-04-21T09:15:23.000Z
# 99  2022-04-21T09:15:23.000Z
#
#                                        public_metrics                   id  \
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...  1517069532451545088
# 1   {'retweet_count': 54, 'reply_count': 0, 'like_...  1517069531562319872
# 2   {'retweet_count': 5687, 'reply_count': 0, 'lik...  1517069531289878528
# 3   {'retweet_count': 2, 'reply_count': 0, 'like_c...  1517069530605961218
# 4   {'retweet_count': 20, 'reply_count': 0, 'like_...  1517069530341773313
# ..                                                ...                  ...
# 95  {'retweet_count': 78, 'reply_count': 0, 'like_...  1517069477925376000
# 96  {'retweet_count': 0, 'reply_count': 0, 'like_c...  1517069477346643969
# 97  {'retweet_count': 5297, 'reply_count': 0, 'lik...  1517069477158223872
# 98  {'retweet_count': 207, 'reply_count': 0, 'like...  1517069476432596992
# 99  {'retweet_count': 7050, 'reply_count': 0, 'lik...  1517069475052494848
#
#    lang
# 0   und
# 1    en
# 2    ja
# 3    ca
# 4    en
# ..  ...
# 95   en
# 96   en
# 97   en
# 98   th
# 99   en
#
# [100 rows x 6 columns]

# %%
tweets = tweets[tweets.lang == 'en']

# %%
result = []
for row in tweets.loc[:,"text"]:
    result.append(clean_text(row))
tweets["clean_tweet"] = result

result = []
for row in tweets.loc[:,"clean_tweet"]:
    result.append(remove_stop_words(row))
    
tweets["final_tweet"] = result
# Out:
# C:\Users\Daria\AppData\Local\Temp/ipykernel_17932/557362867.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets["clean_tweet"] = result
# C:\Users\Daria\AppData\Local\Temp/ipykernel_17932/557362867.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets["final_tweet"] = result

# %%
tweets
# Out:
#                                                  text                   id  \
# 1   RT @OriginalRamayan: @KyivIndependent 'SpaceX ...  1516443905364955137
# 2   RT @_InThisTogether: And the title of the link...  1516443905180553223
# 4                   @Ahmedmaq00 @Arm_Of_Bucky Ukraine  1516443905042300930
# 5   RT @bulatov00: the world and history will take...  1516443904773603337
# 6   RT @simon_schama: In a wide-ranging conversati...  1516443904056340485
# ..                                                ...                  ...
# 95  @JoeBiden Dear Joe Biden need support to Ukrai...  1516443883240140804
# 96  @RT_com's account has been withheld in Portuga...  1516443882518679561
# 97  RT @RepSwalwell: Trump has always rooted for R...  1516443882136883203
# 98  RT @JackDetsch: JUST IN: US is set to deliver ...  1516443882095267843
# 99  Albina Derkach testifies there was no humanita...  1516443881864404999
#
#    lang                created_at  \
# 1    en  2022-04-19T15:49:35.000Z
# 2    en  2022-04-19T15:49:35.000Z
# 4    en  2022-04-19T15:49:35.000Z
# 5    en  2022-04-19T15:49:35.000Z
# 6    en  2022-04-19T15:49:35.000Z
# ..  ...                       ...
# 95   en  2022-04-19T15:49:30.000Z
# 96   en  2022-04-19T15:49:30.000Z
# 97   en  2022-04-19T15:49:30.000Z
# 98   en  2022-04-19T15:49:30.000Z
# 99   en  2022-04-19T15:49:30.000Z
#
#                                        public_metrics               source  \
# 1   {'retweet_count': 2, 'reply_count': 0, 'like_c...   Twitter for iPhone
# 2   {'retweet_count': 14, 'reply_count': 0, 'like_...     Twitter for iPad
# 4   {'retweet_count': 0, 'reply_count': 0, 'like_c...   Twitter for iPhone
# 5   {'retweet_count': 2, 'reply_count': 0, 'like_c...  Twitter for Android
# 6   {'retweet_count': 169, 'reply_count': 0, 'like...      Twitter Web App
# ..                                                ...                  ...
# 95  {'retweet_count': 0, 'reply_count': 0, 'like_c...  Twitter for Android
# 96  {'retweet_count': 150, 'reply_count': 0, 'like...   Twitter for iPhone
# 97  {'retweet_count': 2193, 'reply_count': 0, 'lik...   Twitter for iPhone
# 98  {'retweet_count': 53, 'reply_count': 0, 'like_...  Twitter for Android
# 99  {'retweet_count': 0, 'reply_count': 0, 'like_c...   Twitter for iPhone
#
#                                              withheld  \
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  {'copyright': False, 'country_codes': ['AT', '...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                           clean_tweet  \
# 1   rt starlink terminals sent to ukraine cost us ...
# 2   rt and the title of the linked imf warns of so...
# 4                                             ukraine
# 5   rt the world and history will take from russia...
# 6   rt in a conversation at his compound in volody...
# ..                                                ...
# 95  dear joe biden need support to i am advisor of...
# 96  account has been withheld in czech belgium in ...
# 97  rt trump has always rooted for he was an ameri...
# 98  rt just us is set to deliver seven more flight...
# 99  albina derkach testifies there was no humanita...
#
#                                           final_tweet
# 1   starlink terminals sent ukraine cost us taxpay...
# 2   title linked imf warns social unrest effects a...
# 4                                             ukraine
# 5   world history take russia much russian missile...
# 6   conversation compound volodymyr zelensky tells...
# ..                                                ...
# 95  dear joe biden need support advisor know wrote...
# 96  account withheld czech belgium response legal ...
# 97  trump always rooted american essentially worki...
# 98  us set deliver seven flights military aid ukra...
# 99  albina derkach testifies humanitarian aid mari...
#
# [85 rows x 9 columns]

# %% [markdown]
# ## Feature extraction

# %%
#cv = CountVectorizer()
tweets_cv = cv.transform(tweets["final_tweet"])

# %%
tweets_cv.shape
# Out:
# (85, 26894)

# %% [markdown]
# ## Classification

# %%
predictions = LG.predict(tweets_cv)

# %%
# class 0 is normal tweets and class 1 is toxic/hate/offensive tweets 
np.unique(predictions, return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([68, 17], dtype=int64))

# %%
for i in range(len(tweets)):
	print(tweets.iloc[i, 8], predictions[i])
# Out:
# starlink terminals sent ukraine cost us taxpayers report money really well 0
# title linked imf warns social unrest effects actions 0
# ukraine 0
# world history take russia much russian missiles take every lost life 0
# conversation compound volodymyr zelensky tells atlantic ukraine needs 0
# ukraine hello name anna ukrainian artist currently works 0
# due counteroffensive donetsk armed forces restored full control maryinka key frontline towns since several days ago russians tried seize general staff 0
# even tell much russians loved show screenshot 0
# us clear russia keeps calling us allies enemies threatening obvious patriotism translates support translates support russia 1
# know making new heart think going happen 0
# attack brutal attack war aggression violating human 0
# nationalist writer nikolai starikov says ordinary russians want country tougher ukraine citizens 1
# netherlands send heavy including armoured vehicles ukraine 0
# actual alpha men fighting genocide tuckums friends 0
# william chang christina ying liu flexiworld sues lexmark patent lawsuit 0
# send heavy including armored dutch prime minister mark rutte said 1
# nazis fight 1
# look forward mass surrender armed forces pray united states allows 0
# gaza 0
# meadow red viburnum bent glorious ukraine 0
# boys still one squads sends 1
# good piece scale soviet chinese supplies heavy weaponry north vietnamese dwarfs 1
# realize whole war happening nato funded nazis drive wedge 1
# attack ukraine brutal attack war aggression violating human 0
# volunteers fighting ukraine treated prisoners war 0
# thanks malcolm nance ground always american 2016 told us 0
# beginning total 130 contract military personnel selected serve 42 parts southern military 22 already refused participate 1
# opinion ukraine faces new phase west must washington post 0
# friends created good website presenting different options help 0
# ukraine wants buy 200 marder infantry fighting vehicles germany since early germany given dozens 0
# russia change regime ukraine got ass going 1
# war domino triggering global spike prices cost 0
# yet know full human cost invasion ukraine visit cemetery gives 0
# dan crenshaw making tik tok video walking airport maskless day malcolm nance 0
# sergei lavrov tells indian tv regime change said 25 feb 1
# received call russian foreign minister sergei stressed need respect international law 1
# finally prepared ready share new series heaven project 0
# dan crenshaw making tik tok video walking airport maskless day malcolm nance 0
# still saying politicians conservatives racist still using power show bias race 1
# us set deliver seven flights military aid ukraine region next 24 senior 0
# hague week reporting invictus prince harry meghan met us 0
# debut rolling ukraine decisively defeated russia battle 0
# telephone calls russia launches another massive attack 0
# people spent 20 years telling us winning war afghanistan telling us 0
# say previously agreed upon russia state aggressor country detracts agreement without consent aggressor war waged russia ukraine war 0
# ukraine hello name anna ukrainian artist currently works 0
# 2nd phase special matter exactly 0
# imagine war pause 3 0
# netherlands send heavy including armoured vehicles ukraine 0
# ukraine wants buy 200 marder infantry fighting vehicles germany since early germany given dozens 0
# imposing new sanctions 14 close associates russian regime including two adult 0
# president recorded message ever believe 1
# day 55 ukraine russia starts new offensive azovstal 0
# brandon lewis interview full pm nothing wrong apologises fully 0
# ukraine wants buy 200 marder infantry fighting vehicles germany since early germany given dozens 0
# 2nd phase special matter exactly 0
# today another day hungarian government blocks military assistance deliveries today another day hungarian government betrays european today another day hungarian government works support russian war crimes 0
# ukraine wants buy 200 marder infantry fighting vehicles germany since early germany given dozens 0
# russian victory mariupol city falls would free 12 battalion tactical groups fight 0
# russian embassy ghana sends strong message war 0
# life changes life changes ordinary didion ukraine 0
# eastern offensive 0
# 1100 german medical doctors registered go romania neighboring countries 0
# month promising week mercenary aiden aslin says 0
# imposing new sanctions 14 close associates russian regime including two adult 0
# would republicans complaining biden gotten military aid ukraine preferred 0
# dan crenshaw making tik tok video walking airport maskless day malcolm nance 0
# send heavy including armored dutch prime minister mark rutte said 1
# malcolm counterterrorism expert former msnbc said monday joined legion 0
# genuinely cats dogs protecting newborn ukraine 0
# us set deliver seven flights military aid ukraine region next 24 senior 0
# ukraine wins germany correct current next end russian something 0
# interested ukranian call learn 1
# ukraine flag bio 0
# heart rending tweet see apologists helped syrian dictator 1
# good morning david happy make better midst helping ukraine refugees bombed russian 0
# ukraine wants buy 200 marder infantry fighting vehicles germany since early germany given dozens 0
# good piece scale soviet chinese supplies heavy weaponry north vietnamese dwarfs 1
# xi outsmarts china secretly sends russia weapons via serbia 0
# seven flights weapons heading europe next 24 hours carrying weaponry ukraine senior 0
# dear joe biden need support advisor know wrote believe number live whole world love father love father always ask god office love 0
# account withheld czech belgium response legal learn 0
# trump always rooted american essentially working rooting 0
# us set deliver seven flights military aid ukraine region next 24 senior 0
# albina derkach testifies humanitarian aid mariupol city help people 0
